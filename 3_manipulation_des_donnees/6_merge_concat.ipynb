# %% [markdown]
# Jointure

# %%
import pandas as pd 
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'], 'data1': range(7)})
df1
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2 = pd.DataFrame({'key': ['a', 'b', 'd'], 'data2': range(3)})
df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %%
pd.concat([df1, df2], axis =1)["key"]
# Out:
#   key  key
# 0   b    a
# 1   b    b
# 2   a    d
# 3   c  NaN
# 4   a  NaN
# 5   a  NaN
# 6   b  NaN

# %%
# Par défaut, la jointure se fait sur la clé commune, avec le mode "left"
pd.merge(df1, df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
# S'il n'y a pas de clé commune 
df3 = pd.DataFrame({'lkey': ['b', 'b', 'a', 'c', 'a', 'a', 'b'], 'data1': range(7)})
df4 = pd.DataFrame({'rkey': ['a', 'b', 'd'], 'data2': range(3)})

pd.merge(df3, df4, left_on="lkey", right_on="rkey")
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
# Différents modes de jointure
pd.merge(df1, df2, how="right")
# Out:
#   key  data1  data2
# 0   a    2.0      0
# 1   a    4.0      0
# 2   a    5.0      0
# 3   b    0.0      1
# 4   b    1.0      1
# 5   b    6.0      1
# 6   d    NaN      2

# %% [markdown]
# Concatenation

# %%
# Par défaut, la concaténation est verticale
pd.concat([df1, df2])
# Out:
#   key  data1  data2
# 0   b    0.0    NaN
# 1   b    1.0    NaN
# 2   a    2.0    NaN
# 3   c    3.0    NaN
# 4   a    4.0    NaN
# 5   a    5.0    NaN
# 6   b    6.0    NaN
# 0   a    NaN    0.0
# 1   b    NaN    1.0
# 2   d    NaN    2.0

# %%
pd.concat([df1, df2], axis=1)
# Out:
#   key  data1  key  data2
# 0   b      0    a    0.0
# 1   b      1    b    1.0
# 2   a      2    d    2.0
# 3   c      3  NaN    NaN
# 4   a      4  NaN    NaN
# 5   a      5  NaN    NaN
# 6   b      6  NaN    NaN

# %%
# Concat avec mode de jointure
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e']) 
s3 = pd.Series([5, 6], index=['f', 'g'])
s4 = pd.concat([s1 * 5, s3])

# %%
s1
# Out:
# a    0
# b    1
# dtype: int64

# %%
s4
# Out:
# a    0
# b    5
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1, s4], axis=1, join='inner')
# Out:
#    0  1
# a  0  0
# b  1  5

# %%
pd.concat([s1, s4], axis=1, join='outer')
# Out:
#      0  1
# a  0.0  0
# b  1.0  5
# f  NaN  5
# g  NaN  6

# %% [markdown]
# Exercice

# %%
# A partir des données du Titanic, on souhaite créer une nouvelle colonne "prix moyen custom" qui correspond au prix moyen par catégorie "Pclass" et "Sex"


# Pour cela : 
# 1. commencer par définir un nouveau dataframe issu d'une opération groupby-agrégation
# 2. Faire une jointure pour rattacher ce dataframe au données du Titanic


import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df_titanic = pd.read_csv(url)

df_grouped = df_titanic.groupby(["Pclass", "Sex"])["Fare"].agg('mean')

df_grouped_renamed = df_grouped.rename("prix_moyen_custom")

pd.merge(df_titanic, df_grouped_renamed, on = ["Pclass", "Sex"])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  prix_moyen_custom
# 0        0         A/5 21171   7.2500   NaN        S          12.661633
# 1        0          PC 17599  71.2833   C85        C         106.125798
# 2        0  STON/O2. 3101282   7.9250   NaN        S          16.118810
# 3        0            113803  53.1000  C123        S         106.125798
# 4        0            373450   8.0500   NaN        S          12.661633
# ..     ...               ...      ...   ...      ...                ...
# 886      0            211536  13.0000   NaN        S          19.741782
# 887      0            112053  30.0000   B42        S         106.125798
# 888      2        W./C. 6607  23.4500   NaN        S          16.118810
# 889      0            111369  30.0000  C148        C          67.226127
# 890      0            370376   7.7500   NaN        Q          12.661633
#
# [891 rows x 13 columns]

# %%
# Bonus : niveau avancé
# Une meilleure façon de faire : avec la fonction .transform()
df_titanic["prix moyen custom"] = df_titanic.groupby(["Pclass", "Sex"])["Fare"].transform("mean")
df_titanic.sort_values(["Pclass", "Sex"])
# Out:
#      PassengerId  Survived  Pclass  \
# 498          499         0       1
# 224          225         1       1
# 660          661         1       1
# 339          340         0       1
# 857          858         1       1
# 23            24         1       1
# 472          473         1       2
# 277          278         0       2
# 594          595         0       2
# 8              9         1       3
# 727          728         1       3
# 39            40         1       3
# 40            41         0       3
# 367          368         1       3
# 753          754         0       3
# 465          466         0       3
# 352          353         0       3
# 804          805         1       3
# 81            82         1       3
# 746          747         0       3
# 146          147         1       3
# 521          522         0       3
# 266          267         0       3
# 725          726         0       3
# 57            58         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 498    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# 224                       Hoyt, Mr. Frederick Maxfield    male  38.0      1
# 660                      Frauenthal, Dr. Henry William    male  50.0      2
# 339                       Blackwell, Mr. Stephen Weart    male  45.0      0
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 472            West, Mrs. Edwy Arthur (Ada Mary Worth)  female  33.0      1
# 277                        Parkes, Mr. Francis "Frank"    male   NaN      0
# 594                            Chapman, Mr. John Henry    male  37.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 727                           Mannion, Miss. Margareth  female   NaN      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 367                     Moussa, Mrs. (Mantoura Boulos)  female   NaN      0
# 753                                 Jonkoff, Mr. Lalio    male  23.0      0
# 465                    Goncalves, Mr. Manuel Estanslas    male  38.0      0
# 352                                 Elias, Mr. Tannous    male  15.0      1
# 804                            Hedman, Mr. Oskar Arvid    male  27.0      0
# 81                         Sheerlinck, Mr. Jan Baptist    male  29.0      0
# 746                        Abbott, Mr. Rossmore Edward    male  16.0      1
# 146       Andersson, Mr. August Edvard ("Wennerstrom")    male  27.0      0
# 521                                    Vovk, Mr. Janko    male  22.0      0
# 266                          Panula, Mr. Ernesti Arvid    male  16.0      4
# 725                                Oreskovic, Mr. Luka    male  20.0      0
# 57                                 Novel, Mr. Mansouer    male  28.5      0
#
#      Parch              Ticket      Fare    Cabin Embarked  prix moyen custom
# 498      2              113781  151.5500  C22 C26        S         151.550000
# 224      0               19943   90.0000      C93        S          64.240000
# 660      0            PC 17611  133.6500      NaN        S          64.240000
# 339      0              113784   35.5000        T        S          64.240000
# 857      0              113055   26.5500      E17        S          64.240000
# 23       0              113788   35.5000       A6        S          64.240000
# 472      2          C.A. 34651   27.7500      NaN        S          27.750000
# 277      0              239853    0.0000      NaN        S          13.000000
# 594      0         SC/AH 29037   26.0000      NaN        S          13.000000
# 8        2              347742   11.1333      NaN        S           9.363340
# 727      0               36866    7.7375      NaN        Q           9.363340
# 39       0                2651   11.2417      NaN        C           9.363340
# 40       0                7546    9.4750      NaN        S           9.363340
# 367      0                2626    7.2292      NaN        C           9.363340
# 753      0              349204    7.8958      NaN        S          11.833709
# 465      0  SOTON/O.Q. 3101306    7.0500      NaN        S          11.833709
# 352      1                2695    7.2292      NaN        C          11.833709
# 804      0              347089    6.9750      NaN        S          11.833709
# 81       0              345779    9.5000      NaN        S          11.833709
# 746      1           C.A. 2673   20.2500      NaN        S          11.833709
# 146      0              350043    7.7958      NaN        S          11.833709
# 521      0              349252    7.8958      NaN        S          11.833709
# 266      1             3101295   39.6875      NaN        S          11.833709
# 725      0              315094    8.6625      NaN        S          11.833709
# 57       0                2697    7.2292      NaN        C          11.833709
